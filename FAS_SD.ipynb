# %%
# @title *===* [   **基础设置**   ]  *====*
from IPython.utils import capture
from IPython.display import clear_output

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
# !pip install -q wget

# !wget https://huggingface.co/datasets/FASOXO/FAS_Colab_Stable_diffusion/resolve/main/Colab/FASSD.zip
# !unzip FASSD.zip
# %cd /content
Stable_diffusion版本 = "automatic1111_new"  #@param ["Camenduru_new", "automatic1111_new", "Camenduru_2_3","loading_sd" ]
Stable_diffusion界面 = "NONE" #@param ["NONE","lobe_sd_ui", "Catppuccin", "kitchen"]
controlnet模型 = True #@param {type:"boolean"}
链接谷歌网盘 = False #@param {type:"boolean"}
自带插件 = True #@param {type:"boolean"}
#@markdown > 避免Stable-Diffusion-webui更新后，插件更新进度跟不上导致的报错
初始模型名字 = "FasiMix.safetensors" #@param {type:"string"}
初始模型直链 = "https://civitai.com/api/download/models/143897" #@param {type:"string"}
# %cd /content/ipynbFASSD
# %run FASSDyilai.ipynb
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title *下载文件-1*
# %cd /content/stable-diffusion-{FAS}
# by FAS法斯 喵~
#请按照格式要求更换
#不适合小白
#+-----------------------------+
#模型格式!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M 下载直链 -d /content/stable-diffusion-{FAS}/models/Stable-diffusion -o 名字.safetensors
#Lora格式：!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M 下载直链 -d /content/stable-diffusion-{FAS}/models/Lora -o 名字.safetensors
#vae格式：!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M 下载直链 -d /content/stable-diffusion-{FAS}/models/VAE -o 名字.vae.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://gist.githubusercontent.com/journey-ad/d98ed173321658be6e51f752d6e6163c/raw/aa162c81d9d7d7b6efdffa84ccbfe867be6b711d/I18N_sd-webui-zh_CN.json -d /contect/stable-diffusion-{FAS}/localizations -o I18N_sd-webui-zh_CN.json

clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title Checkpoints/safetensors等大模型下载
def download_file(download, url, filename):
    if download:
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url} -d /contect/stable-diffusion-{FAS}/Stable-diffusion -o {filename}

#@markdown - _下载任务1_
CS_download1 = True #@param {type:"boolean"}
CS_url1 = "https://huggingface.co/swl-models/NullStyle-v2.0/resolve/main/NullStyle-v2.0.safetensors" #@param {type:"string"}
CS_filename1 = "NullStyle-v2.0.safetensors" #@param {type:"string"}

#@markdown - _下载任务2_
CS_download2 = False #@param {type:"boolean"}
CS_url2 = "" #@param {type:"string"}
CS_filename2 = "" #@param {type:"string"}

#@markdown - _下载任务3_
CS_download3 = False #@param {type:"boolean"}
CS_url3 = "" #@param {type:"string"}
CS_filename3 = "" #@param {type:"string"}

#@markdown - _下载任务4_
CS_download4 = False #@param {type:"boolean"}
CS_url4 = "" #@param {type:"string"}
CS_filename4 = "" #@param {type:"string"}

#@markdown - _下载任务5_
CS_download5 = False #@param {type:"boolean"}
CS_url5 = "" #@param {type:"string"}
CS_filename5 = "" #@param {type:"string"}

#@markdown - _下载任务6_
CS_download6 = False #@param {type:"boolean"}
CS_url6 = "" #@param {type:"string"}
CS_filename6 = "" #@param {type:"string"}

#@markdown - _下载任务7_
CS_download7 = False #@param {type:"boolean"}
CS_url7 = "" #@param {type:"string"}
CS_filename7 = "" #@param {type:"string"}

download_file(CS_download1, CS_url1, CS_filename1)
download_file(CS_download2, CS_url2, CS_filename2)
download_file(CS_download3, CS_url3, CS_filename3)
download_file(CS_download4, CS_url4, CS_filename4)
download_file(CS_download5, CS_url5, CS_filename5)
download_file(CS_download6, CS_url6, CS_filename6)
download_file(CS_download7, CS_url7, CS_filename7)
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title Lora模型下载
#@markdown - _下载任务1_
Lora_download = True #@param {type:"boolean"}
Lora_url1 = "https://civitai.com/api/download/models/64842" #@param {type:"string"}
Lora_filename1 = "arona_puranalora_v1.safetensors" #@param {type:"string"}

#@markdown - _下载任务2_
Lora_download2 = False #@param {type:"boolean"}
Lora_url2 = "" #@param {type:"string"}
Lora_filename2 = "" #@param {type:"string"}

#@markdown - _下载任务3_
Lora_download3 = True #@param {type:"boolean"}
Lora_url3 = "https://civitai.com/api/download/models/52900" #@param {type:"string"}
Lora_filename3 = "cailaiarona-000007.safetensors" #@param {type:"string"}

#@markdown - _下载任务4_
Lora_download4 = True #@param {type:"boolean"}
Lora_url4 = "https://civitai.com/api/download/models/9409" #@param {type:"string"}
Lora_filename4 = "chara-arona-v1.safetensors" #@param {type:"string"}

#@markdown - _下载任务5_
Lora_download5 = False #@param {type:"boolean"}
Lora_url5 = "" #@param {type:"string"}
Lora_filename5 = "" #@param {type:"string"}

#@markdown - _下载任务6_
Lora_download6 = False #@param {type:"boolean"}
Lora_url6 = "" #@param {type:"string"}
Lora_filename6 = "" #@param {type:"string"}

def download_file(download, url, filename):
    if download:
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url} -d /contect/stable-diffusion-{FAS}/Lora -o {filename}

download_file(Lora_download, Lora_url1, Lora_filename1)
download_file(Lora_download2, Lora_url2, Lora_filename2)
download_file(Lora_download3, Lora_url3, Lora_filename3)
download_file(Lora_download4, Lora_url4, Lora_filename4)
download_file(Lora_download5, Lora_url5, Lora_filename5)
download_file(Lora_download6, Lora_url6, Lora_filename6)
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title VAE下载
def download_file(download, url, filename):
    if download:
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url} -d /contect/stable-diffusion-{FAS}/VAE -o {filename}

#@markdown - _下载任务1_
VAE_download1 = False #@param {type:"boolean"}
VAE_url1 = "https://huggingface.co/admruul/anything-v3.0/resolve/main/Anything-V3.0.vae.pt" #@param {type:"string"}
VAE_filename1 = "Anything-V3.0.vae.pt" #@param {type:"string"}

#@markdown - _下载任务2_
VAE_download2 = False #@param {type:"boolean"}
VAE_url2 = "https://civitai.com/api/download/models/131654?type=Model&format=SafeTensor" #@param {type:"string"}
VAE_filename2 = "anythingKlF8Anime2VaeFtMse840000_klF8Anime2.safetensors" #@param {type:"string"}

#@markdown - _下载任务3_
VAE_download3 = True #@param {type:"boolean"}
VAE_url3 = "" #@param {type:"string"}
VAE_filename3 = "" #@param {type:"string"}

#@markdown - _下载任务4_
VAE_download4 = False #@param {type:"boolean"}
VAE_url4 = "" #@param {type:"string"}
VAE_filename4 = "" #@param {type:"string"}

#@markdown - _下载任务5_
VAE_download5 = False #@param {type:"boolean"}
VAE_url5 = "" #@param {type:"string"}
VAE_filename5 = "" #@param {type:"string"}

#@markdown - _下载任务6_
VAE_download6 = False #@param {type:"boolean"}
VAE_url6 = "" #@param {type:"string"}
VAE_filename6 = "" #@param {type:"string"}

#@markdown - _下载任务7_
VAE_download7 = False #@param {type:"boolean"}
VAE_url7 = "" #@param {type:"string"}
VAE_filename7 = "" #@param {type:"string"}

#@markdown - _下载任务8_
VAE_download8 = False #@param {type:"boolean"}
VAE_url8 = "" #@param {type:"string"}
VAE_filename8 = "" #@param {type:"string"}

download_file(VAE_download1, VAE_url1, VAE_filename1)
download_file(VAE_download2, VAE_url2, VAE_filename2)
download_file(VAE_download3, VAE_url3, VAE_filename3)
download_file(VAE_download4, VAE_url4, VAE_filename4)
download_file(VAE_download5, VAE_url5, VAE_filename5)
download_file(VAE_download6, VAE_url6, VAE_filename6)
download_file(VAE_download7, VAE_url7, VAE_filename7)
download_file(VAE_download8, VAE_url8, VAE_filename8)
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title embeddings模型下载
def download_embeddings(download, url, filename):
    if download:
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url} -d /contect/stable-diffusion-{FAS}/embeddings -o {filename}

#@markdown - _下载任务1_
embeddings_download1 = True #@param {type:"boolean"}
embeddings_url1 = "https://civitai.com/api/download/models/125849" #@param {type:"string"}
embeddings_filename1 = "bad-hands-5.pt" #@param {type:"string"}

#@markdown - _下载任务2_
embeddings_download2 = False #@param {type:"boolean"}
embeddings_url2 = "" #@param {type:"string"}
embeddings_filename2 = "" #@param {type:"string"}

#@markdown - _下载任务3_
embeddings_download3 = False #@param {type:"boolean"}
embeddings_url3 = "" #@param {type:"string"}
embeddings_filename3 = "" #@param {type:"string"}

#@markdown - _下载任务4_
embeddings_download4 = False #@param {type:"boolean"}
embeddings_url4 = "" #@param {type:"string"}
embeddings_filename4 = "" #@param {type:"string"}

#@markdown - _下载任务5_
embeddings_download5 = False #@param {type:"boolean"}
embeddings_url5 = "" #@param {type:"string"}
embeddings_filename5 = "" #@param {type:"string"}

download_embeddings(embeddings_download1, embeddings_url1, embeddings_filename1)
download_embeddings(embeddings_download2, embeddings_url2, embeddings_filename2)
download_embeddings(embeddings_download3, embeddings_url3, embeddings_filename3)
download_embeddings(embeddings_download4, embeddings_url4, embeddings_filename4)
download_embeddings(embeddings_download5, embeddings_url5, embeddings_filename5)
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title **额外下载** | *不使用可删除*
# %cd /content
#@markdown > 此模块删除不会影响其它代码使用
额外模型1 = "Anything_V5"#@param ["NONE","Counterfeit3","CuteYukiMix3","QteaMix通用Q版模型","天空之境","Anything_V5","AICE冰可","TMND_Mix","GhostMix3","AICE冰可","AbyssOrangeMix3","PastelMix"]
额外模型2 = "AbyssOrangeMix3"#@param ["NONE","Counterfeit3","CuteYukiMix3","QteaMix通用Q版模型","天空之境","Anything_V5","AICE冰可","TMND_Mix","GhostMix3","AICE冰可","AbyssOrangeMix3","PastelMix"]
额外模型3 = "NONE"#@param ["NONE","Counterfeit3","CuteYukiMix3","QteaMix通用Q版模型","天空之境","Anything_V5","AICE冰可","TMND_Mix","GhostMix3","AICE冰可","AbyssOrangeMix3","PastelMix"]
额外VAE1 = "vae_ft_mse_840000_ema_pruned"#@param ["NONE","vae_ft_mse_840000_ema_pruned","Counterfeit_2_5_vae","clearvae","clearvae_main","kl_f8_anime2","orangemix","pastelvae"]
额外VAE2 = "orangemix"#@param ["NONE","vae_ft_mse_840000_ema_pruned","Counterfeit_2_5_vae","clearvae","clearvae_main","kl_f8_anime2","orangemix","pastelvae"]
额外VAE3 = "Counterfeit_2_5_vae"#@param ["NONE","vae_ft_mse_840000_ema_pruned","Counterfeit_2_5_vae","clearvae","clearvae_main","kl_f8_anime2","orangemix","pastelvae"]
#@markdown > **+- Lora -+**
genshin_impact = False #@param {type:"boolean"}
blue_archive = False #@param {type:"boolean"}
Honkai_impact = False #@param {type:"boolean"}
arknights = False #@param {type:"boolean"}
风格Lora = T #@param {type:"boolean"}
NIKKE = False #@param {type:"boolean"}
#@markdown > **+- embeddings -+**
fas_233embeddings = False #@param {type:"boolean"}
#by FAS法斯
# %cd /content/ipynbFASSD
# %run FASSDxiazai.ipynb
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@title *===* [   **启动设置**   ]  *====*

#@markdown > **<font color = red >** **WARNING** - *请勿使用gradio内网穿透，否则该笔记本停止运行*

自定义启动项 = "--theme dark" #@param {type:"string"}
ngrok令牌 = "2WBwItYs1vYWRtdOBc2X8ba9NA0_36jqmTDy9H7MZsFGJQqBr" #@param {type:"string"}
网络优化 = True #@param {type:"boolean"}
低配置运行 = True #@param {type:"boolean"}
中断重启按钮 = True #@param {type:"boolean"}
启用扩展选项卡 = True #@param {type:"boolean"}
模型全精度 = True #@param {type:"boolean"}
VAE全精度 = True #@param {type:"boolean"}
更多内网穿透 = True #@param {type:"boolean"}
api调用 = True #@param {type:"boolean"}
# %cd /content/ipynbFASSD
# %run FASSDqidon.ipynb
# by 法斯

# %%
#@title *将所有图片变为压缩包*
# !zip -r /content/图片.zip /content/stable-diffusion-{FAS}/outputs
# @markdown > 保存位置/content

# %%
#@title *将图片保存谷歌网盘*
# %cd /content/stable-diffusion-{FAS}/outputs
# !zip -r /content/drive/MyDrive/images.zip txt2img-images
